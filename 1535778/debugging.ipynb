# %%
import os
import re
import glob
import logging
import datetime
import pandas as pd
import numpy as np
from bs4 import BeautifulSoup
from fuzzywuzzy import process

'''
TO DO 
separate issuer investment
make issuer would have company name

June 30 2021

start Black rock capital investment core BKCC (cik==1326003)
'''
# https://www.sec.gov/robots.txt
def get_standard_name(col, choices, score_cutoff=60):
    best_match, score = process.extractOne(col, choices)
    if score > score_cutoff:
        return best_match
    return col

def stopping_criterion(qtr:str)->str:
    return '{}'.format(r'Total\s*Non-Control/Non-Affiliate\s*Investments')

    # if qtr == '2023-12-31':
    #     return '{}'.format(r'Total\s*Cash\s*Equivalents')
    # return '{}'.format(r'Total\s*Investments')
    
def concat(*dfs)->list:
    final = []
    for df in dfs:
        final.extend(df.values.tolist())
    return final

def common_subheaders()->tuple:
    return tuple(map(lambda header:header.replace(' ', r'\s*'),
        ('Advertising, Public Relations and Marketing ',
        'Air Transportation',
        'Amusement and Recreation',
        'Apparel Manufacturing',
        'Building Equipment Contractors',
        'Business Support Services',
        'Chemicals',
        'Communications Equipment Manufacturing',
        'Credit Related Activities',
        'Computer Systems Design and Related Services',
        'Credit (Nondepository)',
        'Data Processing and Hosting Services',
        'Educational Support Services',
        'Electronic Component Manufacturing',
        'Equipment Leasing',
        'Facilities Support Services',
        'Grocery Stores',
        'Hospitals',
        'Insurance',
        'Lessors of Nonfinancial Licenses',
        'Management, Scientific, and Technical Consulting Services',
        'Motion Picture and Video Industries',
        'Other Information Services',
        'Other Manufacturing',
        'Other Publishing',
        'Other Real Estate Activities',
        'Other Telecommunications',
        'Plastics Manufacturing',
        'Radio and Television Broadcasting',
        'Real Estate Leasing',
        'Restaurants',
        'Retail',
        'Satellite Telecommunications',
        'Scientific Research and Development Services',
        'Texttile Furnishings Mills',
        'Traveler Arrangement',
        'Software Publishing',
        'Utility System Construction',
        'Wholesalers',
        'Wired Telecommunications Carriers',
        'Wireless Telecommunications Carriers',
        )
    ))

def standard_field_names()->tuple:
    return (
        'Portfolio Company / Type of Investment',
        'portfolio company',
        'business description',
        'type of investment',
        'investment date',
        'index rate',
        'shares/ units',
        'total rate',
        'reference rate and spread',
        'pik rate',
        'maturity date',
        'principal',
        'cost',
        'footnotes',
        'industry',
        'principal amount', # TODO change stand names for more dynamic fuzzywuzzy matching
        'fair value',
    )

def company_control_headers()->tuple:
    return tuple(map(lambda header:header.replace(' ', r'\s*'),
        (
        'Debt Investments',
        'Debt Investments (82.23%)',
        'Debt Investments (A)',
        'Debt Investments (continued)',
        'Equity Securities',
        'Equity Securities (continued)',
        'Cash and Cash Equivalents',
        )
    ))

def exceptions()->list:
    return [
        '2022-09-30\Schedule_of_Investments_0.csv'
    ]

def except_rows()->list:
    return (
        'As of',
        'HMS Income Fund',
        'schedule of investments'
    )
    
def strip_string(
    columns_names:list,
    standardize:bool=False
)->tuple:
    # columns = tuple(map(lambda col:re.sub(r'[^a-z]', '', str(col).lower()),columns_names))
    if standardize:
        standard_fields = standard_field_names()
        return tuple(
            re.sub(r'\s+', '_',get_standard_name(col,standard_fields)) for col in columns_names
        )
    return tuple(re.sub(r'\s+', '_',col) for col in columns_names)

def get_key_fields(
    df_cur:pd.DataFrame,
)->tuple:
    important_fields = standard_field_names() + common_subheaders()
    for idx,row in enumerate(df_cur.iterrows()):
        found = any(any(
            key in str(field).lower() 
            for key in important_fields)
                    for field in row[-1].dropna().tolist()
            )
        if found and len(set(row[-1].dropna().tolist())) >= 4:
            cols = df_cur.iloc[:idx + 1].apply(lambda row: ' '.join(row.dropna()), axis=0).tolist()
            fields = strip_string(cols,standardize=found) ,idx
            return fields
    return strip_string(df_cur.iloc[0].tolist(),standardize=found),0


# Function to extract date and convert to datetime object
def extract_date(file_path):
    # Extract date from file path (assuming date is always in 'YYYY-MM-DD' format)
    date_str = re.search(r'\d{4}-\d{2}-\d{2}', file_path).group()
    return datetime.datetime.strptime(date_str, '%Y-%m-%d')


def merge_duplicate_columns(
    df:pd.DataFrame,
    merged_pair_idxs:dict={}
)->pd.DataFrame:
    duplicate_cols = merged_pair_idxs.keys()
    flag = not merged_pair_idxs.keys()
    if flag: 
        duplicate_cols = df.columns.unique() 
    for col_name in duplicate_cols:
        mask = merged_pair_idxs.get(col_name)
        if flag:
            mask = df.columns == col_name
            merged_pair_idxs[col_name] = mask
        duplicate_data = df.loc[:, mask]
        merged_data = duplicate_data.apply(lambda row: ' '.join(set(row.dropna().astype(str))), axis=1)
        df = df.loc[:, ~mask]
        df[col_name] = merged_data
    return df.reset_index(drop=True),merged_pair_idxs

def extract_subheaders(
    df:pd.DataFrame,
    control:bool,
)->pd.DataFrame:
    col_name = 'company_control' if control else 'Type_of_Investment'
    if col_name in df.columns:
        return df
    include = df.apply(
        lambda row: re.search('|'.join(company_control_headers() if control else common_subheaders()), str(row[0]), re.IGNORECASE) is not None,
        axis=1
    )  
    
    exclude = ~df.apply(
        lambda row: row.astype(str).str.contains('total|Inc|Ltd|LLC|Holdings|LP|Co|Corporation', case=False, na=False).any(),
        axis=1
    )
    idx = df[include & exclude].index.tolist()
    df[col_name] = None
    if not idx:
        return df

    prev_header = subheader = None
    df.loc[idx[-1]:,col_name] = df.iloc[idx[-1],1] if isinstance(df.iloc[idx[-1],0],float)  else df.iloc[idx[-1],0]
    for j,i in enumerate(idx[:-1]):
        prev_header = subheader
        subheader = df.iloc[i,1] if isinstance(df.iloc[i,0],float)  else df.iloc[i,0]
        df.loc[idx[j]:idx[j+1],col_name] = subheader if subheader != '' else prev_header
    return df


def remove_row_duplicates(row:pd.Series)->pd.Series: 
    out = []
    for v in row:
        if v in out and not v.replace('$','').isnumeric():
            out.append(np.nan)
        else:
            out.append(v)
    return pd.Series(out)


  
def _clean(
    file_path:str,
    except_rows:str,
    merged_pair_idxs:dict={},
)->pd.DataFrame:
    df = pd.read_csv(file_path,index_col=0,na_values=[' ', ''])
    df.replace(['\u200b',None, r'^\s*$'],np.nan,regex=True,inplace=True) #':','$','%'
    df.dropna(axis=0,how='all',inplace=True)

    df = df[~df.apply(lambda row:row.astype(str).str.contains(except_rows,case=False, na=False).any(),axis=1)]
    if not merged_pair_idxs:
        important_fields,idx = get_key_fields(df)
        df.columns = important_fields
    df,merge_pair_idxs = merge_duplicate_columns(df,merged_pair_idxs=merged_pair_idxs)
    display(df)
    duplicate_idx = df.apply(lambda row:row[pd.to_numeric(row,errors='coerce').isna()].duplicated().sum() > 1 ,axis=1)
    clean_rows = df.loc[duplicate_idx].apply(remove_row_duplicates, axis=1).reset_index(drop=True)
    j = 0
    for i,flag in enumerate(duplicate_idx):
        if not flag:
            continue
        df.iloc[i,:] = clean_rows.loc[j,:].tolist()
        j += 1
    df.replace([''],np.nan,regex=True,inplace=True) #':','$','%'
    df.dropna(axis=1,how='all',inplace=True)
    # columns = (~df.isna()).sum(axis=0) < (6 if df.shape[0] > 10 else 2 if df.shape[0] <= 4 else 0)
    columns = [col.isdigit() or col == '' for col in df.columns.tolist()]
    df = df.drop(columns=df.columns[columns])
    return df.reset_index(drop=True),merge_pair_idxs
    
def main()->None:
    qtrs = os.listdir('.')
    ex = exceptions()
    ex_rows = '|'.join(except_rows())
    for qtr in qtrs:
        if '.csv' in qtr or not os.path.exists(os.path.join(qtr,f'Schedule_of_Investments_0.csv')):
            continue
        # qtr = '2016-06-30'
        print(qtr)

        index_list_sum = i = 0
        soi_files = sorted([
            os.path.join(qtr,file) 
            for file in os.listdir(qtr)
            if file.endswith('.csv')
        ],key=lambda f: int(f.split('_')[-1].split('.')[0]))
        soi_files = [f for f in soi_files if f not in ex]
        df,merged_pair_idxs = _clean(soi_files[i],except_rows=ex_rows,merged_pair_idxs={})
        index_list = df.apply(
            lambda row:row.astype(str).str.contains(stopping_criterion(qtr), case=False, na=False).any(),
            axis=1
        )
        index_list_sum = index_list.sum()
        dfs = [df]     
        i += 1
        while index_list_sum == 0:
            print(soi_files[i])
            df,merged_pair_idxs = _clean(soi_files[i],except_rows=ex_rows,merged_pair_idxs=merged_pair_idxs)
            dfs.append(df)
            index_list = df.apply(
                lambda row:row.astype(str).str.contains(stopping_criterion(qtr), case=False, na=False).any(),
                axis=1
            )
            index_list_sum = index_list.sum()
            i += 1
            
        date_final = dfs[0]
        if len(dfs) > 1:
            date_final = pd.concat(dfs,axis=0,ignore_index=True)#pd.DataFrame(concat(*dfs))
        # date_final = extract_subheaders(date_final,control=True)
        # date_final = extract_subheaders(date_final,control=False)

        date_final['qtr'] = qtr.split('\\')[-1]
        if not os.path.exists(os.path.join(qtr,'output')):
            os.makedirs(os.path.join(qtr,'output'))
        columns_to_drop = date_final.notna().sum() <= 2
        date_final.drop(columns=columns_to_drop[columns_to_drop].index)
        date_final.to_csv(os.path.join(qtr,'output',f'{qtr}.csv'),index=False)
        # break
    
    # Use glob to find files
    files = sorted(glob.glob(f'*/output/*.csv'), key=extract_date)
    single_truth = pd.concat([
        pd.read_csv(df) for df in files
    ],axis=0,ignore_index=True)
    single_truth.drop(columns=single_truth.columns[['Unnamed' in col for col in single_truth.columns]],inplace=True)
    single_truth.to_csv(f'{cik}_soi_table.csv',index=False)
    
    
# from utils import init_logger
import warnings

# Suppress future warnings
warnings.simplefilter(action='ignore', category=FutureWarning)
warnings.filterwarnings('ignore', category=pd.errors.SettingWithCopyWarning)
# init_logger()
cik = 1535778
# main()
# Out:
# /home/tony/anaconda3/envs/sec/lib/python3.6/site-packages/fuzzywuzzy/fuzz.py:11: UserWarning: Using slow pure-python SequenceMatcher. Install python-Levenshtein to remove this warning
#   warnings.warn('Using slow pure-python SequenceMatcher. Install python-Levenshtein to remove this warning')
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-2-39c48cb5ade9> in <module>
#     319 # Suppress future warnings
#     320 warnings.simplefilter(action='ignore', category=FutureWarning)
# --> 321 warnings.filterwarnings('ignore', category=pd.errors.SettingWithCopyWarning)
#     322 # init_logger()
#     323 cik = 1535778
#
# AttributeError: module 'pandas.errors' has no attribute 'SettingWithCopyWarning'

# %%
file_path = "1535778/2014-03-31/Schedule_of_Investments_1.csv"

def remove_row_duplicates(row:pd.Series)->pd.Series: 
    out = []
    for v in row:
        if v in out and not v.replace('$','').isnumeric():
            out.append(np.nan)
        else:
            out.append(v)
    return pd.Series(out)

def stopping_criterion(qtr:str)->str:
    return '{}'.format(r'Total\s*Non-Control/Non-Affiliate\s*Investments')

def _clean(
    file_path:str,
    except_rows:str,
    merged_pair_idxs:dict={},
)->pd.DataFrame:
    df = pd.read_csv(file_path,index_col=0,na_values=[' ', ''])
    df.replace(['\u200b',None, r'^\s*$'],np.nan,regex=True,inplace=True) #':','$','%'
    df.dropna(axis=0,how='all',inplace=True)

    df = df[~df.apply(lambda row:row.astype(str).str.contains(except_rows,case=False, na=False).any(),axis=1)]
    if not merged_pair_idxs:
        important_fields,idx = get_key_fields(df)
        df.columns = important_fields
    df,merge_pair_idxs = merge_duplicate_columns(df,merged_pair_idxs=merged_pair_idxs)
    display(df)
    duplicate_idx = df.apply(lambda row:row[pd.to_numeric(row,errors='coerce').isna()].duplicated().sum() > 1 ,axis=1)
    clean_rows = df.loc[duplicate_idx].apply(remove_row_duplicates, axis=1).reset_index(drop=True)
    j = 0
    for i,flag in enumerate(duplicate_idx):
        if not flag:
            continue
        df.iloc[i,:] = clean_rows.loc[j,:].tolist()
        j += 1
    df.replace([''],np.nan,regex=True,inplace=True) #':','$','%'
    df.dropna(axis=1,how='all',inplace=True)
    # columns = (~df.isna()).sum(axis=0) < (6 if df.shape[0] > 10 else 2 if df.shape[0] <= 4 else 0)
    columns = [col.isdigit() or col == '' for col in df.columns.tolist()]
    df = df.drop(columns=df.columns[columns])
    return df.reset_index(drop=True),merge_pair_idxs


ex_rows = '|'.join(except_rows())
df,merged_pair_idxs = _clean(file_path,except_rows=ex_rows)
display(df.head(50))
display(merged_pair_idxs)
index_list = df.apply(
    lambda row:row.astype(str).str.contains(stopping_criterion(None), case=False, na=False).any(),
    axis=1
)
index_list_sum = index_list.sum()
index_list_sum
# Out:
#                                     portfolio_company  \
# 0                               Portfolio Company (1)
# 1           Non-Control/Non-Affiliate Investments (2)
# 2                ABG Intermediate Holdings 2, LLC (6)
# 3                  Allflex Holdings III Inc. (6) (11)
# 4          Ameritech College Operations, LLC (8) (10)
# ..                                                ...
# 66                        Visant Corporation (6) (10)
# 67                         Vision Solutions, Inc. (6)
# 68                   Walker & Dunlop Inc. (6) (7) (9)
# 69                                YP Holdings LLC (6)
# 70  Total Non-Control/Non-Affiliate Investments (2...
#
#                                  business_description  \
# 0                                Business Description
# 1           Non-Control/Non-Affiliate Investments (2)
# 2                     Trademark Licensing of Clothing
# 3   Manufacturer of Livestock Identification Products
# 4           For-Profit Nursing and Healthcare College
# ..                                                ...
# 66                             School Affinity Stores
# 67      Provider of Information Availability Software
# 68                     Real Estate Financial Services
# 69            Online and Offline Advertising Operator
# 70  Total Non-Control/Non-Affiliate Investments (2...
#
#                                    type_of_investment  \
# 0                              Type of Investment (1)
# 1           Non-Control/Non-Affiliate Investments (2)
# 2   LIBOR Plus 5.00%, Current Coupon 6.00%, Secure...
# 3   LIBOR Plus 7.00%, Current Coupon 8.00%, Secure...
# 4         18% Secured Debt (Maturity - March 9, 2017)
# ..                                                ...
# 66  LIBOR Plus 4.00%, Current Coupon 5.25%, Secure...
# 67  LIBOR Plus 4.50%, Current Coupon 6.00%, Secure...
# 68  LIBOR Plus 4.50%, Current Coupon 5.50%, Secure...
# 69  LIBOR Plus 6.75%, Current Coupon 8.00%, Secure...
# 70  Total Non-Control/Non-Affiliate Investments (2...
#
#                                     principal  \
# 0                               Principal (5)
# 1   Non-Control/Non-Affiliate Investments (2)
# 2                                      1500 $
# 3                                         950
# 4                                         750
# ..                                        ...
# 66                                        691
# 67                                       1000
# 68                                        750
# 69                                        700
# 70
#
#                                          cost  \
# 0                                    Cost (5)
# 1   Non-Control/Non-Affiliate Investments (2)
# 2                                      $ 1492
# 3                                         969
# 4                                         750
# ..                                        ...
# 66                                        691
# 67                                        990
# 68                                        743
# 69                                        682
# 70                                    66410 $
#
#                                    fair_value
# 0                                  Fair Value
# 1   Non-Control/Non-Affiliate Investments (2)
# 2                                      $ 1496
# 3                                         964
# 4                                         750
# ..                                        ...
# 66                                        683
# 67                                       1004
# 68                                        746
# 69                                        709
# 70                                    66882 $
#
# [71 rows x 6 columns]
#                                     portfolio_company  \
# 0                               Portfolio Company (1)
# 1           Non-Control/Non-Affiliate Investments (2)
# 2                ABG Intermediate Holdings 2, LLC (6)
# 3                  Allflex Holdings III Inc. (6) (11)
# 4          Ameritech College Operations, LLC (8) (10)
# 5                       AMF Bowling Centers, Inc. (6)
# 6                          Ancile Solutions, Inc. (6)
# 7                         Answers Corporation (6) (9)
# 8                    Apria Healthcare Group, Inc. (6)
# 9                                  Artel, LLC (6) (9)
# 10          Atkins Nutritionals Holdings II, Inc. (6)
# 11                               BBTS Borrower LP (6)
# 12                  Blackhawk Specialty Tools LLC (6)
# 13                          Bluestem Brands, Inc. (6)
# 14  California Healthcare Medical Billing, Inc. (8...
# 15                       CDC Software Corporation (6)
# 16                Cedar Bay Generation Company LP (6)
# 17                Collective Brands Finance, Inc. (6)
# 18                                e-Rewards, Inc. (6)
# 19                   Excelitas Technologies Corp. (6)
# 20         Fender Musical Instruments Corporation (6)
# 21                         FishNet Security, Inc. (6)
# 22                  Fram Group Holdings, Inc. (6) (9)
# 23                             Getty Images, Inc. (6)
# 24                            Golden Nugget, Inc. (6)
# 25                     iEnergizer Limited (6) (7) (9)
# 26         Inn of the Mountain Gods Resort and Casino
# 27                         Ipreo Holdings LLC (6) (9)
# 28                Jackson Hewitt Tax Service Inc. (6)
# 29                        Joernes Healthcare, LLC (6)
# 30            Keypoint Government Solutions, Inc. (6)
# 31                       Larchmont Resources, LLC (6)
# 32            Learning Care Group (US) No. 2 Inc. (6)
# 33                   LJ Host Merger Sub, Inc. (6) (9)
# 34                                                NaN
# 35                                                NaN
# 36                         MAH Merger Corporation (6)
# 37                            MediMedia USA, Inc. (6)
# 38                    MedSolutions Holdings, Inc. (6)
# 39                        Mitel US Holdings, Inc. (6)
# 40                          MP Assets Corporation (6)
# 41                          National Vision, Inc. (6)
# 42                         Neenah Foundry Company (6)
# 43                     NRC US Holding Company LLC (6)
# 44                     Orbitz Worldwide, Inc. (6) (7)
# 45         Panolam Industries International, Inc. (6)
# 46                             Permian Holdings, Inc.
# 47          Pitney Bowes Management Services Inc. (6)
# 48                     Polyconcept Financial B.V. (6)
# 49              Ravago Holdings America, Inc. (6) (9)
#
#                                  business_description  \
# 0                                Business Description
# 1                                                 NaN
# 2                     Trademark Licensing of Clothing
# 3   Manufacturer of Livestock Identification Products
# 4           For-Profit Nursing and Healthcare College
# 5                              Bowling Alley Operator
# 6                     Provider of eLearning Solutions
# 7          Consumer Internet Search Services Provider
# 8                           Home Healthcare Equipment
# 9        Land-Based and Commercial Satellite Provider
# 10                    Weight Management Food Products
# 11       Oil & Gas Exploration and Midstream Services
# 12                      Oilfield Equipment & Services
# 13      Multi-Channel Retailer of General Merchandise
# 14      Outsourced Billing & Revenue Cycle Management
# 15                    Enterprise Application Software
# 16                      Coal-Fired Cogeneration Plant
# 17                        Specialty Footwear Retailer
# 18                Provider of Digital Data Collection
# 19                     Lighting and Sensor Components
# 20                Manufacturer of Musical Instruments
# 21        Information Technology Value-Added Reseller
# 22    Manufacturer of Automotive Maintenance Products
# 23  Digital Photography and Video Content Marketplace
# 24        Hotels & Casinos in Las Vegas and Louisiana
# 25         Provider of Business Outsourcing Solutions
# 26                                     Hotel & Casino
# 27           Application Software for Capital Markets
# 28                           Tax Preparation Services
# 29                   Health Care Equipment & Supplies
# 30                  Pre-Employment Screening Services
# 31                 Oil & Gas Exploration & Production
# 32              Provider of Early Childhood Education
# 33              Managed Services and Hosting Provider
# 34                                                NaN
# 35                                                NaN
# 36                  Sports-Themed Casual Dining Chain
# 37        Provider of Health Care Media and Marketing
# 38                       Specialty Benefit Management
# 39                 Manufacturer of Battery Components
# 40                 Manufacturer of Battery Components
# 41                          Discount Optical Retailer
# 42                         Operator of Iron Foundries
# 43                    Environmental Services Provider
# 44                                Online Travel Agent
# 45                   Decorative Laminate Manufacturer
# 46                          Storage Tank Manufacturer
# 47           Provider of Document Management Services
# 48  Promotional Products to Corporations and Consu...
# 49                               Polymers Distributor
#
#                                    type_of_investment      principal  \
# 0                              Type of Investment (1)  Principal (5)
# 1                                                 NaN            NaN
# 2   LIBOR Plus 5.00%, Current Coupon 6.00%, Secure...         1500 $
# 3   LIBOR Plus 7.00%, Current Coupon 8.00%, Secure...            950
# 4         18% Secured Debt (Maturity - March 9, 2017)            750
# 5   LIBOR Plus 7.50%, Current Coupon 8.75%, Secure...            988
# 6   LIBOR Plus 5.00%, Current Coupon 6.25%, Secure...           1234
# 7   LIBOR Plus 5.50%, Current Coupon 6.50%, Secure...           1500
# 8   LIBOR Plus 5.50%, Current Coupon 6.75%, Secure...            995
# 9   LIBOR Plus 6.00%, Current Coupon 7.25%, Secure...           1188
# 10  LIBOR Plus 5.00%, Current Coupon 6.25%, Secure...            993
# 11  LIBOR Plus 6.50%, Current Coupon 7.75%, Secure...           1489
# 12  LIBOR Plus 5.25%, Current Coupon 6.50%, Secure...           1500
# 13  LIBOR Plus 6.50%, Current Coupon 7.50%, Secure...           1000
# 14    12% Secured Debt, (Maturity - October 17, 2015)            750
# 15  LIBOR Plus 6.00%, Current Coupon 7.25%, Secure...            743
# 16  LIBOR Plus 5.00%, Current Coupon 6.25%, Secure...            885
# 17  LIBOR Plus 6.00%, Current Coupon 7.25%, Secure...            496
# 18  LIBOR Plus 5.00%, Current Coupon 6.00%, Secure...           1000
# 19  LIBOR Plus 5.00%, Current Coupon 6.00%, Secure...            989
# 20  LIBOR Plus 4.50%, Current Coupon 5.75%, Secure...            448
# 21  LIBOR Plus 5.00%, Current Coupon 6.25%, Secure...           1980
# 22  LIBOR Plus 5.00%, Current Coupon 6.50%, Secure...           1500
# 23  LIBOR Plus 3.50%, Current Coupon 4.75%, Secure...            997
# 24  LIBOR Plus 4.50%, Current Coupon 5.50%, Secure...            700
# 25  LIBOR Plus 6.00%, Current Coupon 7.25%, Secure...           1437
# 26  9.25% Secured Bond (Maturity - November 30, 2020)           1000
# 27  LIBOR Plus 4.00%, Current Coupon 5.00%, Secure...            732
# 28  LIBOR Plus 8.50%, Current Coupon 10.00%, Secur...           1000
# 29  LIBOR Plus 5.00%, Current Coupon 6.25%, Secure...            993
# 30  LIBOR Plus 6.00%, Current Coupon 7.25%, Secure...            920
# 31  LIBOR Plus 7.25%, Current Coupon 8.50%, Secure...            746
# 32  LIBOR Plus 4.75%, Current Coupon 6.00%, Secure...            998
# 33  LIBOR Plus 4.75%, Current Coupon 6.00%, Secure...           1000
# 34  LIBOR Plus 8.75%, Current Coupon 10.00%, Secur...            500
# 35                                                NaN            NaN
# 36  LIBOR Plus 4.50%, Current Coupon 5.75%, Secure...           1500
# 37  LIBOR Plus 6.75%, Current Coupon 8.00%, Secure...            995
# 38  LIBOR Plus 5.25%, Current Coupon 6.50%, Secure...            975
# 39  LIBOR Plus 4.50%, Current Coupon 7.00%, Secure...            893
# 40  LIBOR Plus 4.50%, Current Coupon 5.50%, Secure...           1000
# 41  LIBOR Plus 5.75%, Current Coupon 7.00%, Secure...            730
# 42  LIBOR Plus 5.50%, Current Coupon 6.75%, Secure...             12
# 43  LIBOR Plus 4.50%, Current Coupon 5.50%, Secure...            975
# 44  LIBOR Plus 4.75%, Current Coupon 5.75%, Secure...            498
# 45  LIBOR Plus 6.00%, Current Coupon 7.25%, Secure...            905
# 46  10.50% Secured Bond (Maturity - January 15, 2018)            910
# 47  LIBOR Plus 6.25%, Current Coupon 7.50%, Secure...            998
# 48  LIBOR Plus 4.75%, Current Coupon 6.00%, Secure...            975
# 49  LIBOR Plus 4.50%, Current Coupon 5.50%, Secure...           1250
#
#         cost  fair_value
# 0   Cost (5)  Fair Value
# 1        NaN         NaN
# 2     $ 1492      $ 1496
# 3        969         964
# 4        750         750
# 5        959         995
# 6       1224        1234
# 7       1485        1485
# 8        995        1000
# 9       1152        1170
# 10       983        1005
# 11      1482        1503
# 12      1500        1496
# 13       980         990
# 14       750         750
# 15       737         749
# 16       876         892
# 17       496         499
# 18       980         994
# 19       980         997
# 20       443         455
# 21      1963        1989
# 22      1489        1489
# 23       895         933
# 24       693         712
# 25      1413        1417
# 26       955         968
# 27       732         743
# 28      1000         995
# 29       984         973
# 30       915         910
# 31       750         760
# 32       988        1004
# 33       990         995
# 34       490         498
# 35      1480        1493
# 36      1500        1493
# 37       967         973
# 38       966         974
# 39       884         896
# 40       990         998
# 41       721         732
# 42        12          12
# 43       970         977
# 44       498         500
# 45       897         875
# 46       888         896
# 47       988        1005
# 48       966         979
# 49      1238        1253
# {'portfolio_company': array([ True, False, False, False, False, False, False, False, False,
#         False, False, False]),
#  'business_description': array([ True, False, False, False, False, False, False, False, False,
#         False, False, False]),
#  'type_of_investment': array([ True, False, False, False, False, False, False, False, False,
#         False, False, False]),
#  'principal': array([ True,  True,  True, False, False, False, False, False, False,
#         False, False, False]),
#  'cost': array([ True,  True,  True, False, False, False, False, False, False,
#         False]),
#  'fair_value': array([ True,  True,  True, False, False, False, False, False])}
# 1
